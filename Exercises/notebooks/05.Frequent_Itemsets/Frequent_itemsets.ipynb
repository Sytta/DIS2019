# %% [markdown]
# # Exercise 5

# %% [markdown]
# Today, we will implement two techniques that are part of the so-called shopping basket analysis, which will help us to better understand how customers data are being processed to extract insights about their habits.
#
#
# #### Notes about external libraries
# You can check your implementation of the Apriori algorithm and the Association Rules using MLxtend, a data mining library. Unfortunately, the library is not directly shipped with Anaconda. To install MLxtend, just execute
#
# ```bash
# pip install mlxtend
# ```
#
# Or directly using Anaconda
#
# ```bash
# conda install -c conda-forge mlxtend
# ```
#
# Note that the installation of MLxtend is not mandatory, as we will provide the expected results in pre-rendered cells.
#
# ## Exercise 5.1
#
# In the first part of this excercise, we will put into practice the Apriori algorithm. In particular, we will extract frequent itemsets from a list of transactions coming from a grocery store. You will have to complete the function get_support(...).

# %%
import operator
import numpy as np

"""
Format the transaction dataset.
Expect a list of transaction in the format:
[[1, 3, 4], [2, 3, 5], [1, 2, 3, 5], ...]
"""
def preprocess(dataset):
    unique_items = set()
    for transaction in dataset:
        for item in transaction:
            unique_items.add(item)
       
    # Converting to frozensets to use itemsets as dict key
    unique_items = [frozenset([i]) for i in list(unique_items)]
    
    return unique_items,list(map(set,dataset))


"""
Generate candidates of length n+1 from a list of items, each of length n.

Example:
[{1}, {2}, {5}]          -> [{1, 2}, {1, 5}, {2, 5}]
[{2, 3}, {2, 5}, {3, 5}] -> [{2, 3, 5}]
"""
def generate_candidates(Lk):
    output = []

    # We generate rules of the target size k
    k=len(Lk[0])+1
    
    for i in range(len(Lk)):
        for j in range(i+1, len(Lk)): 
            L1 = list(Lk[i])[:k-2]; 
            L2 = list(Lk[j])[:k-2]
            L1.sort(); 
            L2.sort()

            # Merge sets if first k-2 elements are equal
            # For the case of k<2, generate all possible combinations
            if L1==L2: 
                output.append(Lk[i] | Lk[j])

    return output


"""
Print the results of the apriori algorithm
"""
def print_support(support,max_display=10,min_items=1):
    print('support\t itemset')
    print('-'*30)
    filt_support = {k:v for k,v in support.items() if len(k)>=min_items}
    for s,sup in sorted(filt_support.items(), key=operator.itemgetter(1),reverse=True)[:max_display]:
        print("%.2f" % sup,'\t',set(s))
        
def print_support_mx(df,max_display=10,min_items=1):
    print('support\t itemset')
    print('-'*30)
    lenrow = df['itemsets'].apply(lambda x: len(x))
    df  = df[lenrow>=min_items]
    df  = df.sort_values('support',ascending=False).iloc[:max_display]
    for i,row in df.iterrows():
        print("%.2f" % float(row['support']),'\t',set(row['itemsets']))
        

"""
Run the apriori algorithm

dataset     : list of transactions
min_support : minimum support. Itemsets with support below this threshold
              will be pruned.
L : Frequent item sets. L[0] : [{'a'}, {'b'}]; L[1]: [{'a', 'b'}, {'c', 'd'}]
Support data: Dictioary of frequent itemsets with their corresponding support.
"""
def apriori(dataset, min_support = 0.5):
    unique_items,dataset = preprocess(dataset)
    L1, supportData      = get_support(dataset, unique_items, min_support) # L1 = {'a'} {'b'} {'c'}
    L = [L1]
    k = 0
    
    while True:
        Ck       = generate_candidates(L[k]) # Union 2 single itemset to a composite itemset {'a'}, {'b'} => {'a', 'b'}
        Lk, supK = get_support(dataset, Ck, min_support)
        
        # Is there itemsets of length k that have the minimum support ?
        if len(Lk)>0:
            supportData.update(supK) # rewrite the values in support dict with newly calculated support 
            L.append(Lk) 
            k += 1
        else:
            break # calculates, as min support augments, the itemsets that satitisfies condition
            
    return L, supportData

# %% [markdown]
# ### TODO
#
# The [Apriori Algorithm](https://en.wikipedia.org/wiki/Apriori_algorithm) identifies frequent combinations of items by extending them to larger and larger itemsets (see the generate_candidates function) as long as they appear sufficiently often in a list of transactions.
#
# Compute support for all the candidate itemsets contained in Ck, given the total list of transactions. We already provide the functions to compute candidate itemsets. The support of the itemset $X$ with respect to the list of transactions $T$ is defined as the proportion of transactions $t$ in the dataset which contains the itemset $X$. Support can be computed using the following formula
#
# $$\mathrm{supp}(X) = \frac{|\{t \in T; X \subseteq t\}|}{|T|}$$
#
# After computing the support for each itemset, prune the ones that do not match the minimal specificied support.

# %%
"""
Compute support for each provided itemset by counting the number of
its occurences in the original dataset of transactions.

dataset      : list of transactions, preprocessed using 'preprocess()'
Ck           : list of itemsets to compute support for. 
min_support  : minimum support. Itemsets with support below this threshold
               will be pruned.
              
output       : list of remaining itemsets, after the pruning step. 
support_dict : dictionary containing the support value for each itemset.
"""
def get_support(dataset, Ck, min_support):
    
    # This dictionary should contain the number of appearance of each itemset in the dataset.
    # Itemset in Ck are represented as frozensets and can directly be uses as dictionary keys.
    support_count = {}
    
    for transaction in dataset:
        for candidate in Ck:
            if candidate.issubset(transaction):
                if candidate in support_count:
                    support_count[candidate] += 1
                else:
                    support_count[candidate] = 1
    
    output = []
    support_dict = {}
    for key in support_count:
        # Calculate fraction of presence of itemset over all transactions
        support = support_count[key] / float(len(dataset))
        
        if support >= min_support:
            output.insert(0,key)
            
        support_dict[key] = support
    return output, support_dict

# %% [markdown]
# ### Run

# %%
dataset = [ l.strip().split(',') for i,l in enumerate(open('groceries.csv').readlines())]

L,support = apriori(dataset,min_support=0.01)
print_support(support,10,min_items=2)
# Out:
# support	 itemset
# ------------------------------
# 0.07 	 {'other vegetables', 'whole milk'}
# 0.06 	 {'rolls/buns', 'whole milk'}
# 0.06 	 {'yogurt', 'whole milk'}
# 0.05 	 {'root vegetables', 'whole milk'}
# 0.05 	 {'other vegetables', 'root vegetables'}
# 0.04 	 {'yogurt', 'other vegetables'}
# 0.04 	 {'rolls/buns', 'other vegetables'}
# 0.04 	 {'tropical fruit', 'whole milk'}
# 0.04 	 {'soda', 'whole milk'}
# 0.04 	 {'rolls/buns', 'soda'}

# %% [markdown]
# ### Check
#
# You can check the results of your implementation using MLXtend. Just run the cell below

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori as mx_apriori

df_dummy = pd.get_dummies(pd.Series(dataset).apply(pd.Series).stack()).sum(level=0)
frequent_itemsets = mx_apriori(df_dummy, min_support=0.01, use_colnames=True)
print_support_mx(frequent_itemsets,10,min_items=2)
# Out:
# support	 itemset
# ------------------------------
# 0.07 	 {'whole milk', 'other vegetables'}
# 0.06 	 {'rolls/buns', 'whole milk'}
# 0.06 	 {'yogurt', 'whole milk'}
# 0.05 	 {'root vegetables', 'whole milk'}
# 0.05 	 {'root vegetables', 'other vegetables'}
# 0.04 	 {'yogurt', 'other vegetables'}
# 0.04 	 {'rolls/buns', 'other vegetables'}
# 0.04 	 {'tropical fruit', 'whole milk'}
# 0.04 	 {'soda', 'whole milk'}
# 0.04 	 {'rolls/buns', 'soda'}

# %% [markdown]
# ## Question 5.2
#
# Such associations are not necessarily symmetric. Therefore, in the second part, we will use [association rule learning](https://en.wikipedia.org/wiki/Association_rule_learning) to better understand the directionality of our computed frequent itemsets. In other terms, we will have to infer if the purchase of one item generally implies the the purchase of another.

# %%
"""
L              : itemsets
supportData    : dictionary storing itemsets support
min_confidence : rules with a confidence under this threshold should be pruned
"""
def generate_rules(L, supportData, min_confidence=0.7):  
    # Rules to be computed
    rules = []
    
    # Iterate over itemsets of length 2..N
    for i in range(1, len(L)):
        
        # Iterate over each frequent itemset
        for freqSet in L[i]:
            H1 = [frozenset([item]) for item in freqSet]
#             print("H1: {}".format(H1))
            # If the itemset contains more than 2 elements
            # recursively generate candidates 
            if (i+1 > 2):
                rules_from_consequent(freqSet, H1, supportData, rules, min_confidence)
                compute_confidence(freqSet, H1, supportData, rules, min_confidence)
            # If the itemsset contains 2 or less elements
            # conpute rule confidence
            else:
                compute_confidence(freqSet, H1, supportData, rules, min_confidence)

    return rules   

"""
freqSet        : frequent itemset
H              : candidate elements to create a rule
supportData    : dictionary storing itemsets support
rules          : array to store rules
min_confidence : rules with a confidence under this threshold should be pruned
"""
def rules_from_consequent(freqSet, H, supportData, rules, min_confidence=0.7):
    m = len(H[0])
#     print("H: {}".format(H))
    if (len(freqSet) > (m + 1)): 

        # create new candidates of size n+1 i.e. merge individual sets
        Hmp1 = generate_candidates(H)
        Hmp1 = compute_confidence(freqSet, Hmp1, supportData, rules, min_confidence)
        
        if (len(Hmp1) > 1):    #need at least two sets to merge
            rules_from_consequent(freqSet, Hmp1, supportData, rules, min_confidence)
            
"""
Print the resulting rules
"""
def print_rules(rules,max_display=10):
    print('confidence\t rule')
    print('-'*30)
    for a,b,sup in sorted(rules, key=lambda x: x[2],reverse=True)[:max_display]:
        print("%.2f" % sup,'\t',set(a),'->',set(b))
def print_rules_mx(df,max_display=10):
    print('confidence\t rule')
    print('-'*30)
    df  = df.sort_values('confidence',ascending=False).iloc[:max_display]
    for i,row in df.iterrows():
        print("%.2f" % float(row['confidence']),'\t',set(row['antecedants']),'->',set(row['consequents']))

# %% [markdown]
# ### TODO:
#
# You will have to complete the method `compute_confidence(...)`, that computes confidence for a set of candidate rules H and prunes the rules that have a confidence below the specified threshold. Please complete it by computing rules confidence using the following formula:
#
# $$\mathrm{conf}(X \Rightarrow Y) = \mathrm{supp}(X \cup Y) / \mathrm{supp}(X)$$

# %%
"""
Compute confidence for a given set of rules and their respective support

freqSet        : frequent itemset of N-element
H              : list of candidate elements Y1, Y2... that are part of the frequent itemset
supportData    : dictionary storing itemsets support
rules          : array to store rules
min_confidence : rules with a confidence under this threshold should be pruned
"""
def compute_confidence(freqSet, H, supportData, rules, min_confidence=0.7):
    prunedH = [] 
    
    for Y in H:
        # Compute X which is the frequent itemset minus the considered Y
        X           = freqSet - Y
        
#         print("freqSet: {}; X : {}; Y: {}".format(freqSet, X, Y))
        
        # Compute support for both terms
        support_XuY = supportData[freqSet]
        support_X   = supportData[X]
        
        
        # Compute confidence
        conf        = support_XuY / support_X
        
        if conf >= min_confidence: 
            rules.append((X, Y, conf))
            prunedH.append(Y)
#     print()
    return prunedH

# %% [markdown]
# ### Run

# %%
rules=generate_rules(L,support, min_confidence=0.1)
print_rules(rules,10)
# Out:
# H1: [frozenset({'napkins'}), frozenset({'whole milk'})]
# freqSet: frozenset({'napkins', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'napkins'})
# freqSet: frozenset({'napkins', 'whole milk'}); X : frozenset({'napkins'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'domestic eggs'})]
# freqSet: frozenset({'rolls/buns', 'domestic eggs'}); X : frozenset({'domestic eggs'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'domestic eggs'}); X : frozenset({'rolls/buns'}); Y: frozenset({'domestic eggs'})
#
# H1: [frozenset({'shopping bags'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'shopping bags', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'shopping bags'})
# freqSet: frozenset({'shopping bags', 'tropical fruit'}); X : frozenset({'shopping bags'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'whipped/sour cream'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'whipped/sour cream', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'whipped/sour cream'})
# freqSet: frozenset({'whipped/sour cream', 'root vegetables'}); X : frozenset({'whipped/sour cream'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'pork'}), frozenset({'whole milk'})]
# freqSet: frozenset({'pork', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'pork'})
# freqSet: frozenset({'pork', 'whole milk'}); X : frozenset({'pork'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'coffee'}), frozenset({'whole milk'})]
# freqSet: frozenset({'coffee', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'coffee'})
# freqSet: frozenset({'coffee', 'whole milk'}); X : frozenset({'coffee'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'root vegetables'}), frozenset({'whole milk'})]
# freqSet: frozenset({'root vegetables', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'root vegetables'})
# freqSet: frozenset({'root vegetables', 'whole milk'}); X : frozenset({'root vegetables'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'yogurt'}), frozenset({'citrus fruit'})]
# freqSet: frozenset({'yogurt', 'citrus fruit'}); X : frozenset({'citrus fruit'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'citrus fruit'}); X : frozenset({'yogurt'}); Y: frozenset({'citrus fruit'})
#
# H1: [frozenset({'brown bread'}), frozenset({'soda'})]
# freqSet: frozenset({'brown bread', 'soda'}); X : frozenset({'soda'}); Y: frozenset({'brown bread'})
# freqSet: frozenset({'brown bread', 'soda'}); X : frozenset({'brown bread'}); Y: frozenset({'soda'})
#
# H1: [frozenset({'sausage'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'sausage', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'sausage'})
# freqSet: frozenset({'sausage', 'root vegetables'}); X : frozenset({'sausage'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'bottled water'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'bottled water', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'bottled water'})
# freqSet: frozenset({'bottled water', 'other vegetables'}); X : frozenset({'bottled water'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'pork'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'pork', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'pork'})
# freqSet: frozenset({'pork', 'other vegetables'}); X : frozenset({'pork'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'rolls/buns', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'tropical fruit'}); X : frozenset({'rolls/buns'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'bottled water'}), frozenset({'rolls/buns'})]
# freqSet: frozenset({'bottled water', 'rolls/buns'}); X : frozenset({'rolls/buns'}); Y: frozenset({'bottled water'})
# freqSet: frozenset({'bottled water', 'rolls/buns'}); X : frozenset({'bottled water'}); Y: frozenset({'rolls/buns'})
#
# H1: [frozenset({'curd'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'curd', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'curd'})
# freqSet: frozenset({'curd', 'root vegetables'}); X : frozenset({'curd'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'soda'}), frozenset({'newspapers'})]
# freqSet: frozenset({'soda', 'newspapers'}); X : frozenset({'newspapers'}); Y: frozenset({'soda'})
# freqSet: frozenset({'soda', 'newspapers'}); X : frozenset({'soda'}); Y: frozenset({'newspapers'})
#
# H1: [frozenset({'soda'}), frozenset({'pip fruit'})]
# freqSet: frozenset({'soda', 'pip fruit'}); X : frozenset({'pip fruit'}); Y: frozenset({'soda'})
# freqSet: frozenset({'soda', 'pip fruit'}); X : frozenset({'soda'}); Y: frozenset({'pip fruit'})
#
# H1: [frozenset({'sliced cheese'}), frozenset({'whole milk'})]
# freqSet: frozenset({'sliced cheese', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'sliced cheese'})
# freqSet: frozenset({'sliced cheese', 'whole milk'}); X : frozenset({'sliced cheese'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'soda'}), frozenset({'whole milk'})]
# freqSet: frozenset({'soda', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'soda'})
# freqSet: frozenset({'soda', 'whole milk'}); X : frozenset({'soda'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'yogurt'}), frozenset({'margarine'})]
# freqSet: frozenset({'yogurt', 'margarine'}); X : frozenset({'margarine'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'margarine'}); X : frozenset({'yogurt'}); Y: frozenset({'margarine'})
#
# H1: [frozenset({'root vegetables'}), frozenset({'pip fruit'})]
# freqSet: frozenset({'root vegetables', 'pip fruit'}); X : frozenset({'pip fruit'}); Y: frozenset({'root vegetables'})
# freqSet: frozenset({'root vegetables', 'pip fruit'}); X : frozenset({'root vegetables'}); Y: frozenset({'pip fruit'})
#
# H1: [frozenset({'soda'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'soda', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'soda'})
# freqSet: frozenset({'soda', 'root vegetables'}); X : frozenset({'soda'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'yogurt'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'yogurt', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'root vegetables'}); X : frozenset({'yogurt'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'shopping bags'}), frozenset({'whole milk'})]
# freqSet: frozenset({'shopping bags', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'shopping bags'})
# freqSet: frozenset({'shopping bags', 'whole milk'}); X : frozenset({'shopping bags'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'newspapers'})]
# freqSet: frozenset({'rolls/buns', 'newspapers'}); X : frozenset({'newspapers'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'newspapers'}); X : frozenset({'rolls/buns'}); Y: frozenset({'newspapers'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'beef'})]
# freqSet: frozenset({'rolls/buns', 'beef'}); X : frozenset({'beef'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'beef'}); X : frozenset({'rolls/buns'}); Y: frozenset({'beef'})
#
# H1: [frozenset({'whipped/sour cream'}), frozenset({'citrus fruit'})]
# freqSet: frozenset({'whipped/sour cream', 'citrus fruit'}); X : frozenset({'citrus fruit'}); Y: frozenset({'whipped/sour cream'})
# freqSet: frozenset({'whipped/sour cream', 'citrus fruit'}); X : frozenset({'whipped/sour cream'}); Y: frozenset({'citrus fruit'})
#
# H1: [frozenset({'butter'}), frozenset({'whole milk'})]
# freqSet: frozenset({'butter', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'butter'})
# freqSet: frozenset({'butter', 'whole milk'}); X : frozenset({'butter'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'bottled water'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'bottled water', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'bottled water'})
# freqSet: frozenset({'bottled water', 'tropical fruit'}); X : frozenset({'bottled water'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'brown bread'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'brown bread', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'brown bread'})
# freqSet: frozenset({'brown bread', 'root vegetables'}); X : frozenset({'brown bread'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'yogurt'}), frozenset({'frankfurter'})]
# freqSet: frozenset({'yogurt', 'frankfurter'}); X : frozenset({'frankfurter'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'frankfurter'}); X : frozenset({'yogurt'}); Y: frozenset({'frankfurter'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'pork'})]
# freqSet: frozenset({'rolls/buns', 'pork'}); X : frozenset({'pork'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'pork'}); X : frozenset({'rolls/buns'}); Y: frozenset({'pork'})
#
# H1: [frozenset({'salty snack'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'salty snack', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'salty snack'})
# freqSet: frozenset({'salty snack', 'other vegetables'}); X : frozenset({'salty snack'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'yogurt'}), frozenset({'whipped/sour cream'})]
# freqSet: frozenset({'yogurt', 'whipped/sour cream'}); X : frozenset({'whipped/sour cream'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'whipped/sour cream'}); X : frozenset({'yogurt'}); Y: frozenset({'whipped/sour cream'})
#
# H1: [frozenset({'root vegetables'}), frozenset({'newspapers'})]
# freqSet: frozenset({'root vegetables', 'newspapers'}); X : frozenset({'newspapers'}); Y: frozenset({'root vegetables'})
# freqSet: frozenset({'root vegetables', 'newspapers'}); X : frozenset({'root vegetables'}); Y: frozenset({'newspapers'})
#
# H1: [frozenset({'pastry'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'pastry', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'pastry'})
# freqSet: frozenset({'pastry', 'root vegetables'}); X : frozenset({'pastry'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'sausage'}), frozenset({'frankfurter'})]
# freqSet: frozenset({'sausage', 'frankfurter'}); X : frozenset({'frankfurter'}); Y: frozenset({'sausage'})
# freqSet: frozenset({'sausage', 'frankfurter'}); X : frozenset({'sausage'}); Y: frozenset({'frankfurter'})
#
# H1: [frozenset({'sausage'}), frozenset({'whole milk'})]
# freqSet: frozenset({'sausage', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'sausage'})
# freqSet: frozenset({'sausage', 'whole milk'}); X : frozenset({'sausage'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'shopping bags'})]
# freqSet: frozenset({'rolls/buns', 'shopping bags'}); X : frozenset({'shopping bags'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'shopping bags'}); X : frozenset({'rolls/buns'}); Y: frozenset({'shopping bags'})
#
# H1: [frozenset({'bottled water'}), frozenset({'whole milk'})]
# freqSet: frozenset({'bottled water', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'bottled water'})
# freqSet: frozenset({'bottled water', 'whole milk'}); X : frozenset({'bottled water'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'hamburger meat'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'hamburger meat', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'hamburger meat'})
# freqSet: frozenset({'hamburger meat', 'other vegetables'}); X : frozenset({'hamburger meat'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'sausage'}), frozenset({'pip fruit'})]
# freqSet: frozenset({'sausage', 'pip fruit'}); X : frozenset({'pip fruit'}); Y: frozenset({'sausage'})
# freqSet: frozenset({'sausage', 'pip fruit'}); X : frozenset({'sausage'}); Y: frozenset({'pip fruit'})
#
# H1: [frozenset({'pork'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'pork', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'pork'})
# freqSet: frozenset({'pork', 'root vegetables'}); X : frozenset({'pork'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'sugar'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'sugar', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'sugar'})
# freqSet: frozenset({'sugar', 'other vegetables'}); X : frozenset({'sugar'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'yogurt'}), frozenset({'soda'})]
# freqSet: frozenset({'yogurt', 'soda'}); X : frozenset({'soda'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'soda'}); X : frozenset({'yogurt'}); Y: frozenset({'soda'})
#
# H1: [frozenset({'frozen vegetables'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'frozen vegetables', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'frozen vegetables'})
# freqSet: frozenset({'frozen vegetables', 'root vegetables'}); X : frozenset({'frozen vegetables'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'yogurt'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'yogurt', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'tropical fruit'}); X : frozenset({'yogurt'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'chocolate'})]
# freqSet: frozenset({'rolls/buns', 'chocolate'}); X : frozenset({'chocolate'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'chocolate'}); X : frozenset({'rolls/buns'}); Y: frozenset({'chocolate'})
#
# H1: [frozenset({'other vegetables'}), frozenset({'butter'})]
# freqSet: frozenset({'other vegetables', 'butter'}); X : frozenset({'butter'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'butter'}); X : frozenset({'other vegetables'}); Y: frozenset({'butter'})
#
# H1: [frozenset({'fruit/vegetable juice'}), frozenset({'citrus fruit'})]
# freqSet: frozenset({'fruit/vegetable juice', 'citrus fruit'}); X : frozenset({'citrus fruit'}); Y: frozenset({'fruit/vegetable juice'})
# freqSet: frozenset({'fruit/vegetable juice', 'citrus fruit'}); X : frozenset({'fruit/vegetable juice'}); Y: frozenset({'citrus fruit'})
#
# H1: [frozenset({'sausage'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'sausage', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'sausage'})
# freqSet: frozenset({'sausage', 'tropical fruit'}); X : frozenset({'sausage'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'citrus fruit'}), frozenset({'pip fruit'})]
# freqSet: frozenset({'citrus fruit', 'pip fruit'}); X : frozenset({'pip fruit'}); Y: frozenset({'citrus fruit'})
# freqSet: frozenset({'citrus fruit', 'pip fruit'}); X : frozenset({'citrus fruit'}); Y: frozenset({'pip fruit'})
#
# H1: [frozenset({'bottled beer'}), frozenset({'whole milk'})]
# freqSet: frozenset({'bottled beer', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'bottled beer'})
# freqSet: frozenset({'bottled beer', 'whole milk'}); X : frozenset({'bottled beer'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'other vegetables'}), frozenset({'brown bread'})]
# freqSet: frozenset({'other vegetables', 'brown bread'}); X : frozenset({'brown bread'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'brown bread'}); X : frozenset({'other vegetables'}); Y: frozenset({'brown bread'})
#
# H1: [frozenset({'pork'}), frozenset({'soda'})]
# freqSet: frozenset({'pork', 'soda'}); X : frozenset({'soda'}); Y: frozenset({'pork'})
# freqSet: frozenset({'pork', 'soda'}); X : frozenset({'pork'}); Y: frozenset({'soda'})
#
# H1: [frozenset({'butter milk'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'butter milk', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'butter milk'})
# freqSet: frozenset({'butter milk', 'other vegetables'}); X : frozenset({'butter milk'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'soda'}), frozenset({'margarine'})]
# freqSet: frozenset({'soda', 'margarine'}); X : frozenset({'margarine'}); Y: frozenset({'soda'})
# freqSet: frozenset({'soda', 'margarine'}); X : frozenset({'soda'}); Y: frozenset({'margarine'})
#
# H1: [frozenset({'frankfurter'}), frozenset({'whole milk'})]
# freqSet: frozenset({'frankfurter', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'frankfurter'})
# freqSet: frozenset({'frankfurter', 'whole milk'}); X : frozenset({'frankfurter'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'yogurt'}), frozenset({'pastry'})]
# freqSet: frozenset({'yogurt', 'pastry'}); X : frozenset({'pastry'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'pastry'}); X : frozenset({'yogurt'}); Y: frozenset({'pastry'})
#
# H1: [frozenset({'citrus fruit'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'citrus fruit', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'citrus fruit'})
# freqSet: frozenset({'citrus fruit', 'tropical fruit'}); X : frozenset({'citrus fruit'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'chocolate'}), frozenset({'soda'})]
# freqSet: frozenset({'chocolate', 'soda'}); X : frozenset({'soda'}); Y: frozenset({'chocolate'})
# freqSet: frozenset({'chocolate', 'soda'}); X : frozenset({'chocolate'}); Y: frozenset({'soda'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'rolls/buns', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'root vegetables'}); X : frozenset({'rolls/buns'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'pastry'}), frozenset({'sausage'})]
# freqSet: frozenset({'pastry', 'sausage'}); X : frozenset({'sausage'}); Y: frozenset({'pastry'})
# freqSet: frozenset({'pastry', 'sausage'}); X : frozenset({'pastry'}); Y: frozenset({'sausage'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'pastry'})]
# freqSet: frozenset({'rolls/buns', 'pastry'}); X : frozenset({'pastry'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'pastry'}); X : frozenset({'rolls/buns'}); Y: frozenset({'pastry'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'whole milk'})]
# freqSet: frozenset({'rolls/buns', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'whole milk'}); X : frozenset({'rolls/buns'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'cream cheese '}), frozenset({'whole milk'})]
# freqSet: frozenset({'cream cheese ', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'cream cheese '})
# freqSet: frozenset({'cream cheese ', 'whole milk'}); X : frozenset({'cream cheese '}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'berries'}), frozenset({'yogurt'})]
# freqSet: frozenset({'berries', 'yogurt'}); X : frozenset({'yogurt'}); Y: frozenset({'berries'})
# freqSet: frozenset({'berries', 'yogurt'}); X : frozenset({'berries'}); Y: frozenset({'yogurt'})
#
# H1: [frozenset({'curd'}), frozenset({'whole milk'})]
# freqSet: frozenset({'curd', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'curd'})
# freqSet: frozenset({'curd', 'whole milk'}); X : frozenset({'curd'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'brown bread'}), frozenset({'whole milk'})]
# freqSet: frozenset({'brown bread', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'brown bread'})
# freqSet: frozenset({'brown bread', 'whole milk'}); X : frozenset({'brown bread'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'domestic eggs'}), frozenset({'citrus fruit'})]
# freqSet: frozenset({'domestic eggs', 'citrus fruit'}); X : frozenset({'citrus fruit'}); Y: frozenset({'domestic eggs'})
# freqSet: frozenset({'domestic eggs', 'citrus fruit'}); X : frozenset({'domestic eggs'}); Y: frozenset({'citrus fruit'})
#
# H1: [frozenset({'brown bread'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'brown bread', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'brown bread'})
# freqSet: frozenset({'brown bread', 'tropical fruit'}); X : frozenset({'brown bread'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'pip fruit'}), frozenset({'whole milk'})]
# freqSet: frozenset({'pip fruit', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'pip fruit'})
# freqSet: frozenset({'pip fruit', 'whole milk'}); X : frozenset({'pip fruit'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'citrus fruit'})]
# freqSet: frozenset({'rolls/buns', 'citrus fruit'}); X : frozenset({'citrus fruit'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'citrus fruit'}); X : frozenset({'rolls/buns'}); Y: frozenset({'citrus fruit'})
#
# H1: [frozenset({'fruit/vegetable juice'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'fruit/vegetable juice', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'fruit/vegetable juice'})
# freqSet: frozenset({'fruit/vegetable juice', 'other vegetables'}); X : frozenset({'fruit/vegetable juice'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'bottled water'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'bottled water', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'bottled water'})
# freqSet: frozenset({'bottled water', 'root vegetables'}); X : frozenset({'bottled water'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'frozen vegetables'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'frozen vegetables', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'frozen vegetables'})
# freqSet: frozenset({'frozen vegetables', 'other vegetables'}); X : frozenset({'frozen vegetables'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'bottled water'}), frozenset({'yogurt'})]
# freqSet: frozenset({'bottled water', 'yogurt'}); X : frozenset({'yogurt'}); Y: frozenset({'bottled water'})
# freqSet: frozenset({'bottled water', 'yogurt'}); X : frozenset({'bottled water'}); Y: frozenset({'yogurt'})
#
# H1: [frozenset({'other vegetables'}), frozenset({'citrus fruit'})]
# freqSet: frozenset({'other vegetables', 'citrus fruit'}); X : frozenset({'citrus fruit'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'citrus fruit'}); X : frozenset({'other vegetables'}); Y: frozenset({'citrus fruit'})
#
# H1: [frozenset({'hygiene articles'}), frozenset({'whole milk'})]
# freqSet: frozenset({'hygiene articles', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'hygiene articles'})
# freqSet: frozenset({'hygiene articles', 'whole milk'}); X : frozenset({'hygiene articles'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'other vegetables'}), frozenset({'domestic eggs'})]
# freqSet: frozenset({'other vegetables', 'domestic eggs'}); X : frozenset({'domestic eggs'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'domestic eggs'}); X : frozenset({'other vegetables'}); Y: frozenset({'domestic eggs'})
#
# H1: [frozenset({'soda'}), frozenset({'white bread'})]
# freqSet: frozenset({'soda', 'white bread'}); X : frozenset({'white bread'}); Y: frozenset({'soda'})
# freqSet: frozenset({'soda', 'white bread'}); X : frozenset({'soda'}); Y: frozenset({'white bread'})
#
# H1: [frozenset({'beef'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'beef', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'beef'})
# freqSet: frozenset({'beef', 'root vegetables'}); X : frozenset({'beef'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'onions'}), frozenset({'whole milk'})]
# freqSet: frozenset({'onions', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'onions'})
# freqSet: frozenset({'onions', 'whole milk'}); X : frozenset({'onions'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'pastry'}), frozenset({'pip fruit'})]
# freqSet: frozenset({'pastry', 'pip fruit'}); X : frozenset({'pip fruit'}); Y: frozenset({'pastry'})
# freqSet: frozenset({'pastry', 'pip fruit'}); X : frozenset({'pastry'}); Y: frozenset({'pip fruit'})
#
# H1: [frozenset({'yogurt'}), frozenset({'sausage'})]
# freqSet: frozenset({'yogurt', 'sausage'}); X : frozenset({'sausage'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'sausage'}); X : frozenset({'yogurt'}); Y: frozenset({'sausage'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'frozen vegetables'})]
# freqSet: frozenset({'rolls/buns', 'frozen vegetables'}); X : frozenset({'frozen vegetables'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'frozen vegetables'}); X : frozenset({'rolls/buns'}); Y: frozenset({'frozen vegetables'})
#
# H1: [frozenset({'dessert'}), frozenset({'whole milk'})]
# freqSet: frozenset({'dessert', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'dessert'})
# freqSet: frozenset({'dessert', 'whole milk'}); X : frozenset({'dessert'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'napkins'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'napkins', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'napkins'})
# freqSet: frozenset({'napkins', 'other vegetables'}); X : frozenset({'napkins'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'berries'}), frozenset({'whole milk'})]
# freqSet: frozenset({'berries', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'berries'})
# freqSet: frozenset({'berries', 'whole milk'}); X : frozenset({'berries'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'shopping bags'}), frozenset({'sausage'})]
# freqSet: frozenset({'shopping bags', 'sausage'}); X : frozenset({'sausage'}); Y: frozenset({'shopping bags'})
# freqSet: frozenset({'shopping bags', 'sausage'}); X : frozenset({'shopping bags'}); Y: frozenset({'sausage'})
#
# H1: [frozenset({'chicken'}), frozenset({'whole milk'})]
# freqSet: frozenset({'chicken', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'chicken'})
# freqSet: frozenset({'chicken', 'whole milk'}); X : frozenset({'chicken'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'pip fruit'})]
# freqSet: frozenset({'rolls/buns', 'pip fruit'}); X : frozenset({'pip fruit'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'pip fruit'}); X : frozenset({'rolls/buns'}); Y: frozenset({'pip fruit'})
#
# H1: [frozenset({'oil'}), frozenset({'whole milk'})]
# freqSet: frozenset({'oil', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'oil'})
# freqSet: frozenset({'oil', 'whole milk'}); X : frozenset({'oil'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'soda'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'soda', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'soda'})
# freqSet: frozenset({'soda', 'tropical fruit'}); X : frozenset({'soda'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'shopping bags'}), frozenset({'soda'})]
# freqSet: frozenset({'shopping bags', 'soda'}); X : frozenset({'soda'}); Y: frozenset({'shopping bags'})
# freqSet: frozenset({'shopping bags', 'soda'}); X : frozenset({'shopping bags'}); Y: frozenset({'soda'})
#
# H1: [frozenset({'other vegetables'}), frozenset({'pip fruit'})]
# freqSet: frozenset({'other vegetables', 'pip fruit'}); X : frozenset({'pip fruit'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'pip fruit'}); X : frozenset({'other vegetables'}); Y: frozenset({'pip fruit'})
#
# H1: [frozenset({'other vegetables'}), frozenset({'newspapers'})]
# freqSet: frozenset({'other vegetables', 'newspapers'}); X : frozenset({'newspapers'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'newspapers'}); X : frozenset({'other vegetables'}); Y: frozenset({'newspapers'})
#
# H1: [frozenset({'whipped/sour cream'}), frozenset({'whole milk'})]
# freqSet: frozenset({'whipped/sour cream', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'whipped/sour cream'})
# freqSet: frozenset({'whipped/sour cream', 'whole milk'}); X : frozenset({'whipped/sour cream'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'canned beer'}), frozenset({'soda'})]
# freqSet: frozenset({'canned beer', 'soda'}); X : frozenset({'soda'}); Y: frozenset({'canned beer'})
# freqSet: frozenset({'canned beer', 'soda'}); X : frozenset({'canned beer'}); Y: frozenset({'soda'})
#
# H1: [frozenset({'chocolate'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'chocolate', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'chocolate'})
# freqSet: frozenset({'chocolate', 'other vegetables'}); X : frozenset({'chocolate'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'cream cheese '}), frozenset({'other vegetables'})]
# freqSet: frozenset({'cream cheese ', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'cream cheese '})
# freqSet: frozenset({'cream cheese ', 'other vegetables'}); X : frozenset({'cream cheese '}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'whipped/sour cream'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'whipped/sour cream', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'whipped/sour cream'})
# freqSet: frozenset({'whipped/sour cream', 'tropical fruit'}); X : frozenset({'whipped/sour cream'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'yogurt'}), frozenset({'domestic eggs'})]
# freqSet: frozenset({'yogurt', 'domestic eggs'}); X : frozenset({'domestic eggs'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'domestic eggs'}); X : frozenset({'yogurt'}); Y: frozenset({'domestic eggs'})
#
# H1: [frozenset({'citrus fruit'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'citrus fruit', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'citrus fruit'})
# freqSet: frozenset({'citrus fruit', 'root vegetables'}); X : frozenset({'citrus fruit'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'bottled beer'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'bottled beer', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'bottled beer'})
# freqSet: frozenset({'bottled beer', 'other vegetables'}); X : frozenset({'bottled beer'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'waffles'}), frozenset({'whole milk'})]
# freqSet: frozenset({'waffles', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'waffles'})
# freqSet: frozenset({'waffles', 'whole milk'}); X : frozenset({'waffles'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'dessert'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'dessert', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'dessert'})
# freqSet: frozenset({'dessert', 'other vegetables'}); X : frozenset({'dessert'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'onions'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'onions', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'onions'})
# freqSet: frozenset({'onions', 'other vegetables'}); X : frozenset({'onions'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'napkins'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'napkins', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'napkins'})
# freqSet: frozenset({'napkins', 'tropical fruit'}); X : frozenset({'napkins'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'long life bakery product'}), frozenset({'whole milk'})]
# freqSet: frozenset({'long life bakery product', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'long life bakery product'})
# freqSet: frozenset({'long life bakery product', 'whole milk'}); X : frozenset({'long life bakery product'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'frankfurter'})]
# freqSet: frozenset({'rolls/buns', 'frankfurter'}); X : frozenset({'frankfurter'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'frankfurter'}); X : frozenset({'rolls/buns'}); Y: frozenset({'frankfurter'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'margarine'})]
# freqSet: frozenset({'rolls/buns', 'margarine'}); X : frozenset({'margarine'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'margarine'}); X : frozenset({'rolls/buns'}); Y: frozenset({'margarine'})
#
# H1: [frozenset({'bottled water'}), frozenset({'pip fruit'})]
# freqSet: frozenset({'bottled water', 'pip fruit'}); X : frozenset({'pip fruit'}); Y: frozenset({'bottled water'})
# freqSet: frozenset({'bottled water', 'pip fruit'}); X : frozenset({'bottled water'}); Y: frozenset({'pip fruit'})
#
# H1: [frozenset({'yogurt'}), frozenset({'beef'})]
# freqSet: frozenset({'yogurt', 'beef'}); X : frozenset({'beef'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'beef'}); X : frozenset({'yogurt'}); Y: frozenset({'beef'})
#
# H1: [frozenset({'sausage'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'sausage', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'sausage'})
# freqSet: frozenset({'sausage', 'other vegetables'}); X : frozenset({'sausage'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'fruit/vegetable juice'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'fruit/vegetable juice', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'fruit/vegetable juice'})
# freqSet: frozenset({'fruit/vegetable juice', 'root vegetables'}); X : frozenset({'fruit/vegetable juice'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'yogurt'}), frozenset({'pip fruit'})]
# freqSet: frozenset({'yogurt', 'pip fruit'}); X : frozenset({'pip fruit'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'pip fruit'}); X : frozenset({'yogurt'}); Y: frozenset({'pip fruit'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'canned beer'})]
# freqSet: frozenset({'rolls/buns', 'canned beer'}); X : frozenset({'canned beer'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'canned beer'}); X : frozenset({'rolls/buns'}); Y: frozenset({'canned beer'})
#
# H1: [frozenset({'beef'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'beef', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'beef'})
# freqSet: frozenset({'beef', 'other vegetables'}); X : frozenset({'beef'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'bottled water'}), frozenset({'soda'})]
# freqSet: frozenset({'bottled water', 'soda'}); X : frozenset({'soda'}); Y: frozenset({'bottled water'})
# freqSet: frozenset({'bottled water', 'soda'}); X : frozenset({'bottled water'}); Y: frozenset({'soda'})
#
# H1: [frozenset({'sausage'}), frozenset({'citrus fruit'})]
# freqSet: frozenset({'sausage', 'citrus fruit'}); X : frozenset({'citrus fruit'}); Y: frozenset({'sausage'})
# freqSet: frozenset({'sausage', 'citrus fruit'}); X : frozenset({'sausage'}); Y: frozenset({'citrus fruit'})
#
# H1: [frozenset({'soda'}), frozenset({'citrus fruit'})]
# freqSet: frozenset({'soda', 'citrus fruit'}); X : frozenset({'citrus fruit'}); Y: frozenset({'soda'})
# freqSet: frozenset({'soda', 'citrus fruit'}); X : frozenset({'soda'}); Y: frozenset({'citrus fruit'})
#
# H1: [frozenset({'other vegetables'}), frozenset({'white bread'})]
# freqSet: frozenset({'other vegetables', 'white bread'}); X : frozenset({'white bread'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'white bread'}); X : frozenset({'other vegetables'}); Y: frozenset({'white bread'})
#
# H1: [frozenset({'tropical fruit'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'tropical fruit', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'tropical fruit'})
# freqSet: frozenset({'tropical fruit', 'root vegetables'}); X : frozenset({'tropical fruit'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'pastry'}), frozenset({'soda'})]
# freqSet: frozenset({'pastry', 'soda'}); X : frozenset({'soda'}); Y: frozenset({'pastry'})
# freqSet: frozenset({'pastry', 'soda'}); X : frozenset({'pastry'}); Y: frozenset({'soda'})
#
# H1: [frozenset({'other vegetables'}), frozenset({'whole milk'})]
# freqSet: frozenset({'other vegetables', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'whole milk'}); X : frozenset({'other vegetables'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'yogurt'}), frozenset({'cream cheese '})]
# freqSet: frozenset({'yogurt', 'cream cheese '}); X : frozenset({'cream cheese '}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'cream cheese '}); X : frozenset({'yogurt'}); Y: frozenset({'cream cheese '})
#
# H1: [frozenset({'fruit/vegetable juice'}), frozenset({'soda'})]
# freqSet: frozenset({'fruit/vegetable juice', 'soda'}); X : frozenset({'soda'}); Y: frozenset({'fruit/vegetable juice'})
# freqSet: frozenset({'fruit/vegetable juice', 'soda'}); X : frozenset({'fruit/vegetable juice'}); Y: frozenset({'soda'})
#
# H1: [frozenset({'yogurt'}), frozenset({'brown bread'})]
# freqSet: frozenset({'yogurt', 'brown bread'}); X : frozenset({'brown bread'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'brown bread'}); X : frozenset({'yogurt'}); Y: frozenset({'brown bread'})
#
# H1: [frozenset({'curd'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'curd', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'curd'})
# freqSet: frozenset({'curd', 'tropical fruit'}); X : frozenset({'curd'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'sausage'})]
# freqSet: frozenset({'rolls/buns', 'sausage'}); X : frozenset({'sausage'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'sausage'}); X : frozenset({'rolls/buns'}); Y: frozenset({'sausage'})
#
# H1: [frozenset({'sausage'}), frozenset({'brown bread'})]
# freqSet: frozenset({'sausage', 'brown bread'}); X : frozenset({'brown bread'}); Y: frozenset({'sausage'})
# freqSet: frozenset({'sausage', 'brown bread'}); X : frozenset({'sausage'}); Y: frozenset({'brown bread'})
#
# H1: [frozenset({'root vegetables'}), frozenset({'chicken'})]
# freqSet: frozenset({'root vegetables', 'chicken'}); X : frozenset({'chicken'}); Y: frozenset({'root vegetables'})
# freqSet: frozenset({'root vegetables', 'chicken'}); X : frozenset({'root vegetables'}); Y: frozenset({'chicken'})
#
# H1: [frozenset({'bottled water'}), frozenset({'shopping bags'})]
# freqSet: frozenset({'bottled water', 'shopping bags'}); X : frozenset({'shopping bags'}); Y: frozenset({'bottled water'})
# freqSet: frozenset({'bottled water', 'shopping bags'}); X : frozenset({'bottled water'}); Y: frozenset({'shopping bags'})
#
# H1: [frozenset({'other vegetables'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'other vegetables', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'tropical fruit'}); X : frozenset({'other vegetables'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'domestic eggs'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'domestic eggs', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'domestic eggs'})
# freqSet: frozenset({'domestic eggs', 'root vegetables'}); X : frozenset({'domestic eggs'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'whipped/sour cream'}), frozenset({'butter'})]
# freqSet: frozenset({'whipped/sour cream', 'butter'}); X : frozenset({'butter'}); Y: frozenset({'whipped/sour cream'})
# freqSet: frozenset({'whipped/sour cream', 'butter'}); X : frozenset({'whipped/sour cream'}); Y: frozenset({'butter'})
#
# H1: [frozenset({'tropical fruit'}), frozenset({'pip fruit'})]
# freqSet: frozenset({'tropical fruit', 'pip fruit'}); X : frozenset({'pip fruit'}); Y: frozenset({'tropical fruit'})
# freqSet: frozenset({'tropical fruit', 'pip fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'pip fruit'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'curd'})]
# freqSet: frozenset({'rolls/buns', 'curd'}); X : frozenset({'curd'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'curd'}); X : frozenset({'rolls/buns'}); Y: frozenset({'curd'})
#
# H1: [frozenset({'fruit/vegetable juice'}), frozenset({'whole milk'})]
# freqSet: frozenset({'fruit/vegetable juice', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'fruit/vegetable juice'})
# freqSet: frozenset({'fruit/vegetable juice', 'whole milk'}); X : frozenset({'fruit/vegetable juice'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'beef'}), frozenset({'whole milk'})]
# freqSet: frozenset({'beef', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'beef'})
# freqSet: frozenset({'beef', 'whole milk'}); X : frozenset({'beef'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'domestic eggs'}), frozenset({'whole milk'})]
# freqSet: frozenset({'domestic eggs', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'domestic eggs'})
# freqSet: frozenset({'domestic eggs', 'whole milk'}); X : frozenset({'domestic eggs'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'butter milk'}), frozenset({'whole milk'})]
# freqSet: frozenset({'butter milk', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'butter milk'})
# freqSet: frozenset({'butter milk', 'whole milk'}); X : frozenset({'butter milk'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'hamburger meat'}), frozenset({'whole milk'})]
# freqSet: frozenset({'hamburger meat', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'hamburger meat'})
# freqSet: frozenset({'hamburger meat', 'whole milk'}); X : frozenset({'hamburger meat'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'fruit/vegetable juice'}), frozenset({'sausage'})]
# freqSet: frozenset({'fruit/vegetable juice', 'sausage'}); X : frozenset({'sausage'}); Y: frozenset({'fruit/vegetable juice'})
# freqSet: frozenset({'fruit/vegetable juice', 'sausage'}); X : frozenset({'fruit/vegetable juice'}); Y: frozenset({'sausage'})
#
# H1: [frozenset({'ham'}), frozenset({'whole milk'})]
# freqSet: frozenset({'ham', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'ham'})
# freqSet: frozenset({'ham', 'whole milk'}); X : frozenset({'ham'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'yogurt'}), frozenset({'curd'})]
# freqSet: frozenset({'yogurt', 'curd'}); X : frozenset({'curd'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'curd'}); X : frozenset({'yogurt'}); Y: frozenset({'curd'})
#
# H1: [frozenset({'yogurt'}), frozenset({'frozen vegetables'})]
# freqSet: frozenset({'yogurt', 'frozen vegetables'}); X : frozenset({'frozen vegetables'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'frozen vegetables'}); X : frozenset({'yogurt'}); Y: frozenset({'frozen vegetables'})
#
# H1: [frozenset({'citrus fruit'}), frozenset({'whole milk'})]
# freqSet: frozenset({'citrus fruit', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'citrus fruit'})
# freqSet: frozenset({'citrus fruit', 'whole milk'}); X : frozenset({'citrus fruit'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'bottled beer'})]
# freqSet: frozenset({'rolls/buns', 'bottled beer'}); X : frozenset({'bottled beer'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'bottled beer'}); X : frozenset({'rolls/buns'}); Y: frozenset({'bottled beer'})
#
# H1: [frozenset({'tropical fruit'}), frozenset({'newspapers'})]
# freqSet: frozenset({'tropical fruit', 'newspapers'}); X : frozenset({'newspapers'}); Y: frozenset({'tropical fruit'})
# freqSet: frozenset({'tropical fruit', 'newspapers'}); X : frozenset({'tropical fruit'}); Y: frozenset({'newspapers'})
#
# H1: [frozenset({'domestic eggs'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'domestic eggs', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'domestic eggs'})
# freqSet: frozenset({'domestic eggs', 'tropical fruit'}); X : frozenset({'domestic eggs'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'long life bakery product'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'long life bakery product', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'long life bakery product'})
# freqSet: frozenset({'long life bakery product', 'other vegetables'}); X : frozenset({'long life bakery product'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'fruit/vegetable juice'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'fruit/vegetable juice', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'fruit/vegetable juice'})
# freqSet: frozenset({'fruit/vegetable juice', 'tropical fruit'}); X : frozenset({'fruit/vegetable juice'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'other vegetables'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'other vegetables', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'root vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'bottled water'}), frozenset({'bottled beer'})]
# freqSet: frozenset({'bottled water', 'bottled beer'}); X : frozenset({'bottled beer'}); Y: frozenset({'bottled water'})
# freqSet: frozenset({'bottled water', 'bottled beer'}); X : frozenset({'bottled water'}); Y: frozenset({'bottled beer'})
#
# H1: [frozenset({'tropical fruit'}), frozenset({'whole milk'})]
# freqSet: frozenset({'tropical fruit', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'tropical fruit'})
# freqSet: frozenset({'tropical fruit', 'whole milk'}); X : frozenset({'tropical fruit'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'pastry'}), frozenset({'tropical fruit'})]
# freqSet: frozenset({'pastry', 'tropical fruit'}); X : frozenset({'tropical fruit'}); Y: frozenset({'pastry'})
# freqSet: frozenset({'pastry', 'tropical fruit'}); X : frozenset({'pastry'}); Y: frozenset({'tropical fruit'})
#
# H1: [frozenset({'shopping bags'}), frozenset({'canned beer'})]
# freqSet: frozenset({'shopping bags', 'canned beer'}); X : frozenset({'canned beer'}); Y: frozenset({'shopping bags'})
# freqSet: frozenset({'shopping bags', 'canned beer'}); X : frozenset({'shopping bags'}); Y: frozenset({'canned beer'})
#
# H1: [frozenset({'bottled water'}), frozenset({'newspapers'})]
# freqSet: frozenset({'bottled water', 'newspapers'}); X : frozenset({'newspapers'}); Y: frozenset({'bottled water'})
# freqSet: frozenset({'bottled water', 'newspapers'}); X : frozenset({'bottled water'}); Y: frozenset({'newspapers'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'whipped/sour cream'})]
# freqSet: frozenset({'rolls/buns', 'whipped/sour cream'}); X : frozenset({'whipped/sour cream'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'whipped/sour cream'}); X : frozenset({'rolls/buns'}); Y: frozenset({'whipped/sour cream'})
#
# H1: [frozenset({'curd'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'curd', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'curd'})
# freqSet: frozenset({'curd', 'other vegetables'}); X : frozenset({'curd'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'bottled water'}), frozenset({'sausage'})]
# freqSet: frozenset({'bottled water', 'sausage'}); X : frozenset({'sausage'}); Y: frozenset({'bottled water'})
# freqSet: frozenset({'bottled water', 'sausage'}); X : frozenset({'bottled water'}); Y: frozenset({'sausage'})
#
# H1: [frozenset({'shopping bags'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'shopping bags', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'shopping bags'})
# freqSet: frozenset({'shopping bags', 'other vegetables'}); X : frozenset({'shopping bags'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'yogurt'}), frozenset({'napkins'})]
# freqSet: frozenset({'yogurt', 'napkins'}); X : frozenset({'napkins'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'napkins'}); X : frozenset({'yogurt'}); Y: frozenset({'napkins'})
#
# H1: [frozenset({'pastry'}), frozenset({'whole milk'})]
# freqSet: frozenset({'pastry', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'pastry'})
# freqSet: frozenset({'pastry', 'whole milk'}); X : frozenset({'pastry'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'sausage'}), frozenset({'soda'})]
# freqSet: frozenset({'sausage', 'soda'}); X : frozenset({'soda'}); Y: frozenset({'sausage'})
# ...
# H: [frozenset({'other vegetables'}), frozenset({'pip fruit'}), frozenset({'whole milk'})]
# freqSet: frozenset({'other vegetables', 'pip fruit', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'other vegetables', 'pip fruit'})
# freqSet: frozenset({'other vegetables', 'pip fruit', 'whole milk'}); X : frozenset({'pip fruit'}); Y: frozenset({'other vegetables', 'whole milk'})
# freqSet: frozenset({'other vegetables', 'pip fruit', 'whole milk'}); X : frozenset({'other vegetables'}); Y: frozenset({'pip fruit', 'whole milk'})
#
# freqSet: frozenset({'other vegetables', 'pip fruit', 'whole milk'}); X : frozenset({'pip fruit', 'whole milk'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'pip fruit', 'whole milk'}); X : frozenset({'other vegetables', 'whole milk'}); Y: frozenset({'pip fruit'})
# freqSet: frozenset({'other vegetables', 'pip fruit', 'whole milk'}); X : frozenset({'other vegetables', 'pip fruit'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'other vegetables'}), frozenset({'citrus fruit'}), frozenset({'whole milk'})]
# H: [frozenset({'other vegetables'}), frozenset({'citrus fruit'}), frozenset({'whole milk'})]
# freqSet: frozenset({'other vegetables', 'citrus fruit', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'other vegetables', 'citrus fruit'})
# freqSet: frozenset({'other vegetables', 'citrus fruit', 'whole milk'}); X : frozenset({'citrus fruit'}); Y: frozenset({'other vegetables', 'whole milk'})
# freqSet: frozenset({'other vegetables', 'citrus fruit', 'whole milk'}); X : frozenset({'other vegetables'}); Y: frozenset({'citrus fruit', 'whole milk'})
#
# freqSet: frozenset({'other vegetables', 'citrus fruit', 'whole milk'}); X : frozenset({'citrus fruit', 'whole milk'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'citrus fruit', 'whole milk'}); X : frozenset({'other vegetables', 'whole milk'}); Y: frozenset({'citrus fruit'})
# freqSet: frozenset({'other vegetables', 'citrus fruit', 'whole milk'}); X : frozenset({'other vegetables', 'citrus fruit'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'yogurt'}), frozenset({'rolls/buns'}), frozenset({'other vegetables'})]
# H: [frozenset({'yogurt'}), frozenset({'rolls/buns'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'yogurt', 'rolls/buns', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'yogurt', 'rolls/buns'})
# freqSet: frozenset({'yogurt', 'rolls/buns', 'other vegetables'}); X : frozenset({'rolls/buns'}); Y: frozenset({'yogurt', 'other vegetables'})
# freqSet: frozenset({'yogurt', 'rolls/buns', 'other vegetables'}); X : frozenset({'yogurt'}); Y: frozenset({'rolls/buns', 'other vegetables'})
#
# freqSet: frozenset({'yogurt', 'rolls/buns', 'other vegetables'}); X : frozenset({'rolls/buns', 'other vegetables'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'rolls/buns', 'other vegetables'}); X : frozenset({'yogurt', 'other vegetables'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'yogurt', 'rolls/buns', 'other vegetables'}); X : frozenset({'yogurt', 'rolls/buns'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'whole milk'}), frozenset({'other vegetables'}), frozenset({'butter'})]
# H: [frozenset({'whole milk'}), frozenset({'other vegetables'}), frozenset({'butter'})]
# freqSet: frozenset({'whole milk', 'other vegetables', 'butter'}); X : frozenset({'butter'}); Y: frozenset({'other vegetables', 'whole milk'})
# freqSet: frozenset({'whole milk', 'other vegetables', 'butter'}); X : frozenset({'other vegetables'}); Y: frozenset({'butter', 'whole milk'})
# freqSet: frozenset({'whole milk', 'other vegetables', 'butter'}); X : frozenset({'whole milk'}); Y: frozenset({'other vegetables', 'butter'})
#
# freqSet: frozenset({'whole milk', 'other vegetables', 'butter'}); X : frozenset({'other vegetables', 'butter'}); Y: frozenset({'whole milk'})
# freqSet: frozenset({'whole milk', 'other vegetables', 'butter'}); X : frozenset({'butter', 'whole milk'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'whole milk', 'other vegetables', 'butter'}); X : frozenset({'other vegetables', 'whole milk'}); Y: frozenset({'butter'})
#
# H1: [frozenset({'other vegetables'}), frozenset({'root vegetables'}), frozenset({'whole milk'})]
# H: [frozenset({'other vegetables'}), frozenset({'root vegetables'}), frozenset({'whole milk'})]
# freqSet: frozenset({'other vegetables', 'root vegetables', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'other vegetables', 'root vegetables'})
# freqSet: frozenset({'other vegetables', 'root vegetables', 'whole milk'}); X : frozenset({'root vegetables'}); Y: frozenset({'other vegetables', 'whole milk'})
# freqSet: frozenset({'other vegetables', 'root vegetables', 'whole milk'}); X : frozenset({'other vegetables'}); Y: frozenset({'root vegetables', 'whole milk'})
#
# H: [frozenset({'other vegetables', 'whole milk'}), frozenset({'root vegetables', 'whole milk'})]
# freqSet: frozenset({'other vegetables', 'root vegetables', 'whole milk'}); X : frozenset({'root vegetables', 'whole milk'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'root vegetables', 'whole milk'}); X : frozenset({'other vegetables', 'whole milk'}); Y: frozenset({'root vegetables'})
# freqSet: frozenset({'other vegetables', 'root vegetables', 'whole milk'}); X : frozenset({'other vegetables', 'root vegetables'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'yogurt'}), frozenset({'soda'}), frozenset({'whole milk'})]
# H: [frozenset({'yogurt'}), frozenset({'soda'}), frozenset({'whole milk'})]
# freqSet: frozenset({'yogurt', 'soda', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'yogurt', 'soda'})
# freqSet: frozenset({'yogurt', 'soda', 'whole milk'}); X : frozenset({'soda'}); Y: frozenset({'yogurt', 'whole milk'})
# freqSet: frozenset({'yogurt', 'soda', 'whole milk'}); X : frozenset({'yogurt'}); Y: frozenset({'soda', 'whole milk'})
#
# freqSet: frozenset({'yogurt', 'soda', 'whole milk'}); X : frozenset({'soda', 'whole milk'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'soda', 'whole milk'}); X : frozenset({'yogurt', 'whole milk'}); Y: frozenset({'soda'})
# freqSet: frozenset({'yogurt', 'soda', 'whole milk'}); X : frozenset({'yogurt', 'soda'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'other vegetables'}), frozenset({'pork'}), frozenset({'whole milk'})]
# H: [frozenset({'other vegetables'}), frozenset({'pork'}), frozenset({'whole milk'})]
# freqSet: frozenset({'other vegetables', 'pork', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'pork', 'other vegetables'})
# freqSet: frozenset({'other vegetables', 'pork', 'whole milk'}); X : frozenset({'pork'}); Y: frozenset({'other vegetables', 'whole milk'})
# freqSet: frozenset({'other vegetables', 'pork', 'whole milk'}); X : frozenset({'other vegetables'}); Y: frozenset({'pork', 'whole milk'})
#
# freqSet: frozenset({'other vegetables', 'pork', 'whole milk'}); X : frozenset({'pork', 'whole milk'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'pork', 'whole milk'}); X : frozenset({'other vegetables', 'whole milk'}); Y: frozenset({'pork'})
# freqSet: frozenset({'other vegetables', 'pork', 'whole milk'}); X : frozenset({'pork', 'other vegetables'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'fruit/vegetable juice'}), frozenset({'other vegetables'}), frozenset({'whole milk'})]
# H: [frozenset({'fruit/vegetable juice'}), frozenset({'other vegetables'}), frozenset({'whole milk'})]
# freqSet: frozenset({'fruit/vegetable juice', 'other vegetables', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'fruit/vegetable juice', 'other vegetables'})
# freqSet: frozenset({'fruit/vegetable juice', 'other vegetables', 'whole milk'}); X : frozenset({'other vegetables'}); Y: frozenset({'fruit/vegetable juice', 'whole milk'})
# freqSet: frozenset({'fruit/vegetable juice', 'other vegetables', 'whole milk'}); X : frozenset({'fruit/vegetable juice'}); Y: frozenset({'other vegetables', 'whole milk'})
#
# freqSet: frozenset({'fruit/vegetable juice', 'other vegetables', 'whole milk'}); X : frozenset({'other vegetables', 'whole milk'}); Y: frozenset({'fruit/vegetable juice'})
# freqSet: frozenset({'fruit/vegetable juice', 'other vegetables', 'whole milk'}); X : frozenset({'fruit/vegetable juice', 'whole milk'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'fruit/vegetable juice', 'other vegetables', 'whole milk'}); X : frozenset({'fruit/vegetable juice', 'other vegetables'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'yogurt'}), frozenset({'whipped/sour cream'}), frozenset({'other vegetables'})]
# H: [frozenset({'yogurt'}), frozenset({'whipped/sour cream'}), frozenset({'other vegetables'})]
# freqSet: frozenset({'yogurt', 'whipped/sour cream', 'other vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'yogurt', 'whipped/sour cream'})
# freqSet: frozenset({'yogurt', 'whipped/sour cream', 'other vegetables'}); X : frozenset({'whipped/sour cream'}); Y: frozenset({'yogurt', 'other vegetables'})
# freqSet: frozenset({'yogurt', 'whipped/sour cream', 'other vegetables'}); X : frozenset({'yogurt'}); Y: frozenset({'whipped/sour cream', 'other vegetables'})
#
# freqSet: frozenset({'yogurt', 'whipped/sour cream', 'other vegetables'}); X : frozenset({'whipped/sour cream', 'other vegetables'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'whipped/sour cream', 'other vegetables'}); X : frozenset({'yogurt', 'other vegetables'}); Y: frozenset({'whipped/sour cream'})
# freqSet: frozenset({'yogurt', 'whipped/sour cream', 'other vegetables'}); X : frozenset({'yogurt', 'whipped/sour cream'}); Y: frozenset({'other vegetables'})
#
# H1: [frozenset({'pastry'}), frozenset({'other vegetables'}), frozenset({'whole milk'})]
# H: [frozenset({'pastry'}), frozenset({'other vegetables'}), frozenset({'whole milk'})]
# freqSet: frozenset({'pastry', 'other vegetables', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'pastry', 'other vegetables'})
# freqSet: frozenset({'pastry', 'other vegetables', 'whole milk'}); X : frozenset({'other vegetables'}); Y: frozenset({'pastry', 'whole milk'})
# freqSet: frozenset({'pastry', 'other vegetables', 'whole milk'}); X : frozenset({'pastry'}); Y: frozenset({'other vegetables', 'whole milk'})
#
# freqSet: frozenset({'pastry', 'other vegetables', 'whole milk'}); X : frozenset({'other vegetables', 'whole milk'}); Y: frozenset({'pastry'})
# freqSet: frozenset({'pastry', 'other vegetables', 'whole milk'}); X : frozenset({'pastry', 'whole milk'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'pastry', 'other vegetables', 'whole milk'}); X : frozenset({'pastry', 'other vegetables'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'root vegetables'}), frozenset({'whole milk'})]
# H: [frozenset({'rolls/buns'}), frozenset({'root vegetables'}), frozenset({'whole milk'})]
# freqSet: frozenset({'rolls/buns', 'root vegetables', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'rolls/buns', 'root vegetables'})
# freqSet: frozenset({'rolls/buns', 'root vegetables', 'whole milk'}); X : frozenset({'root vegetables'}); Y: frozenset({'rolls/buns', 'whole milk'})
# freqSet: frozenset({'rolls/buns', 'root vegetables', 'whole milk'}); X : frozenset({'rolls/buns'}); Y: frozenset({'root vegetables', 'whole milk'})
#
# freqSet: frozenset({'rolls/buns', 'root vegetables', 'whole milk'}); X : frozenset({'root vegetables', 'whole milk'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'root vegetables', 'whole milk'}); X : frozenset({'rolls/buns', 'whole milk'}); Y: frozenset({'root vegetables'})
# freqSet: frozenset({'rolls/buns', 'root vegetables', 'whole milk'}); X : frozenset({'rolls/buns', 'root vegetables'}); Y: frozenset({'whole milk'})
#
# H1: [frozenset({'rolls/buns'}), frozenset({'other vegetables'}), frozenset({'root vegetables'})]
# H: [frozenset({'rolls/buns'}), frozenset({'other vegetables'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'rolls/buns', 'other vegetables', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'rolls/buns', 'other vegetables'})
# freqSet: frozenset({'rolls/buns', 'other vegetables', 'root vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'rolls/buns', 'root vegetables'})
# freqSet: frozenset({'rolls/buns', 'other vegetables', 'root vegetables'}); X : frozenset({'rolls/buns'}); Y: frozenset({'other vegetables', 'root vegetables'})
#
# freqSet: frozenset({'rolls/buns', 'other vegetables', 'root vegetables'}); X : frozenset({'other vegetables', 'root vegetables'}); Y: frozenset({'rolls/buns'})
# freqSet: frozenset({'rolls/buns', 'other vegetables', 'root vegetables'}); X : frozenset({'rolls/buns', 'root vegetables'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'rolls/buns', 'other vegetables', 'root vegetables'}); X : frozenset({'rolls/buns', 'other vegetables'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'other vegetables'}), frozenset({'tropical fruit'}), frozenset({'root vegetables'})]
# H: [frozenset({'other vegetables'}), frozenset({'tropical fruit'}), frozenset({'root vegetables'})]
# freqSet: frozenset({'other vegetables', 'tropical fruit', 'root vegetables'}); X : frozenset({'root vegetables'}); Y: frozenset({'other vegetables', 'tropical fruit'})
# freqSet: frozenset({'other vegetables', 'tropical fruit', 'root vegetables'}); X : frozenset({'tropical fruit'}); Y: frozenset({'other vegetables', 'root vegetables'})
# freqSet: frozenset({'other vegetables', 'tropical fruit', 'root vegetables'}); X : frozenset({'other vegetables'}); Y: frozenset({'tropical fruit', 'root vegetables'})
#
# H: [frozenset({'other vegetables', 'tropical fruit'}), frozenset({'other vegetables', 'root vegetables'})]
# freqSet: frozenset({'other vegetables', 'tropical fruit', 'root vegetables'}); X : frozenset({'tropical fruit', 'root vegetables'}); Y: frozenset({'other vegetables'})
# freqSet: frozenset({'other vegetables', 'tropical fruit', 'root vegetables'}); X : frozenset({'other vegetables', 'root vegetables'}); Y: frozenset({'tropical fruit'})
# freqSet: frozenset({'other vegetables', 'tropical fruit', 'root vegetables'}); X : frozenset({'other vegetables', 'tropical fruit'}); Y: frozenset({'root vegetables'})
#
# H1: [frozenset({'yogurt'}), frozenset({'tropical fruit'}), frozenset({'whole milk'})]
# H: [frozenset({'yogurt'}), frozenset({'tropical fruit'}), frozenset({'whole milk'})]
# freqSet: frozenset({'yogurt', 'tropical fruit', 'whole milk'}); X : frozenset({'whole milk'}); Y: frozenset({'yogurt', 'tropical fruit'})
# freqSet: frozenset({'yogurt', 'tropical fruit', 'whole milk'}); X : frozenset({'tropical fruit'}); Y: frozenset({'yogurt', 'whole milk'})
# freqSet: frozenset({'yogurt', 'tropical fruit', 'whole milk'}); X : frozenset({'yogurt'}); Y: frozenset({'tropical fruit', 'whole milk'})
#
# H: [frozenset({'yogurt', 'whole milk'}), frozenset({'tropical fruit', 'whole milk'})]
# freqSet: frozenset({'yogurt', 'tropical fruit', 'whole milk'}); X : frozenset({'tropical fruit', 'whole milk'}); Y: frozenset({'yogurt'})
# freqSet: frozenset({'yogurt', 'tropical fruit', 'whole milk'}); X : frozenset({'yogurt', 'whole milk'}); Y: frozenset({'tropical fruit'})
# freqSet: frozenset({'yogurt', 'tropical fruit', 'whole milk'}); X : frozenset({'yogurt', 'tropical fruit'}); Y: frozenset({'whole milk'})
#
# confidence	 rule
# ------------------------------
# 0.59 	 {'citrus fruit', 'root vegetables'} -> {'other vegetables'}
# 0.58 	 {'tropical fruit', 'root vegetables'} -> {'other vegetables'}
# 0.58 	 {'yogurt', 'curd'} -> {'whole milk'}
# 0.57 	 {'other vegetables', 'butter'} -> {'whole milk'}
# 0.57 	 {'tropical fruit', 'root vegetables'} -> {'whole milk'}
# 0.56 	 {'yogurt', 'root vegetables'} -> {'whole milk'}
# 0.55 	 {'domestic eggs', 'other vegetables'} -> {'whole milk'}
# 0.52 	 {'yogurt', 'whipped/sour cream'} -> {'whole milk'}
# 0.52 	 {'rolls/buns', 'root vegetables'} -> {'whole milk'}
# 0.52 	 {'other vegetables', 'pip fruit'} -> {'whole milk'}

# %% [markdown]
# ### Check
#
# You can check the results of your implementation using MLXtend. Just run the cell below (you will have to run the checking code of question 1 first).

# %%
from mlxtend.frequent_patterns import association_rules as mx_association_rules

rules_mx = mx_association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)
print_rules_mx(rules_mx,max_display=10)
# Out:
# confidence	 rule
# ------------------------------
# 0.59 	 {'root vegetables', 'citrus fruit'} -> {'other vegetables'}
# 0.58 	 {'tropical fruit', 'root vegetables'} -> {'other vegetables'}
# 0.58 	 {'yogurt', 'curd'} -> {'whole milk'}
# 0.57 	 {'butter', 'other vegetables'} -> {'whole milk'}
# 0.57 	 {'tropical fruit', 'root vegetables'} -> {'whole milk'}
# 0.56 	 {'root vegetables', 'yogurt'} -> {'whole milk'}
# 0.55 	 {'domestic eggs', 'other vegetables'} -> {'whole milk'}
# 0.52 	 {'yogurt', 'whipped/sour cream'} -> {'whole milk'}
# 0.52 	 {'rolls/buns', 'root vegetables'} -> {'whole milk'}
# 0.52 	 {'pip fruit', 'other vegetables'} -> {'whole milk'}

# %% [markdown]
# ## EPFL Twitter Data
#
# Now that we have a working implementation, we will apply the Apriori algorithm on a dataset that you should know pretty well by now: EPFL Twitter data. In that scenario, tweets will be considered as transactions and words will be items. Let's see what kind of frequent associations we can discover.
#
# The method below cleans the tweets and formats them in the same format as the transactions of the previous exercise. Run the cells and generate the results for both algorithms. What can you observe from the association rules results? Briefly explain.

# %%
# Loading of libraries and documents

from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
import string
from nltk.corpus import stopwords
import math
from collections import Counter
nltk.download('stopwords')
nltk.download('punkt')

# Tokenize, stem a document
stemmer = PorterStemmer()
def tokenize(text):
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    return " ".join([stemmer.stem(word.lower()) for word in tokens])

# Remove stop words
def clean_voc(documents):
    cleaned = []
    for tweet in documents:
        new_tweet = []
        tweet = tokenize(tweet).split()
        for word in tweet:
            if (word not in stopwords.words('english') and 
                word not in stopwords.words('german') and
                word not in stopwords.words('french')):
                if word=="epflen":
                    word = "epfl"
                new_tweet.append(word)
        if len(new_tweet)>0:
            cleaned.append(new_tweet)
    return cleaned

# Read a list of documents from a file. Each line in a file is a document
with open("epfldocs.txt") as f:
    content = f.readlines()
original_documents = [x.strip() for x in content] 
documents = clean_voc(original_documents)
# Out:
# [nltk_data] Downloading package stopwords to /Users/yawen/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/yawen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
L,support = apriori(documents,min_support = 0.01)
print_support(support,20,min_items=2)
# Out:
# support	 itemset
# ------------------------------
# 0.08 	 {'epfl', 'via'}
# 0.06 	 {'epfl', '’'}
# 0.05 	 {'epfl', 'new'}
# 0.05 	 {'amp', 'epfl'}
# 0.05 	 {'research', 'epfl'}
# 0.04 	 {'epfl', 'lausann'}
# 0.04 	 {'epfl', 'vdtech'}
# 0.04 	 {'epfl', 'switzerland'}
# 0.04 	 {'robot', 'epfl'}
# 0.03 	 {'epfl', 'day'}
# 0.03 	 {'epfl', 'swiss'}
# 0.03 	 {'via', 'vdtech'}
# 0.03 	 {'epfl', 'via', 'vdtech'}
# 0.03 	 {'innov', 'epfl'}
# 0.03 	 {'epfl', 'scienc'}
# 0.03 	 {'epfl', 'student'}
# 0.03 	 {'epfl', 'first'}
# 0.03 	 {'epfl', 'work'}
# 0.02 	 {'epfl', 'technolog'}
# 0.02 	 {'learn', 'epfl'}

# %%
rules=generate_rules(L,support, min_confidence=0.1)
print_rules(rules,20)
# Out:
# confidence	 rule
# ------------------------------
# 1.00 	 {'scientist'} -> {'epfl'}
# 1.00 	 {'perovskit'} -> {'epfl'}
# 1.00 	 {'epflcampu'} -> {'epfl'}
# 1.00 	 {'technolog'} -> {'epfl'}
# 1.00 	 {'»'} -> {'epfl'}
# 1.00 	 {'»'} -> {'«'}
# 1.00 	 {'«'} -> {'»'}
# 1.00 	 {'«'} -> {'epfl'}
# 1.00 	 {'improv'} -> {'epfl'}
# 1.00 	 {'next'} -> {'epfl'}
# 1.00 	 {'present'} -> {'epfl'}
# 1.00 	 {'eth'} -> {'epfl'}
# 1.00 	 {'learn'} -> {'epfl'}
# 1.00 	 {'show'} -> {'epfl'}
# 1.00 	 {'drone'} -> {'epfl'}
# 1.00 	 {'model'} -> {'epfl'}
# 1.00 	 {'particip'} -> {'epfl'}
# 1.00 	 {'mooc'} -> {'epfl'}
# 1.00 	 {'brain'} -> {'epfl'}
# 1.00 	 {'»'} -> {'«', 'epfl'}

# %% [markdown]
# ## 5.3 Pen and Paper

# %% [markdown]
# You are given the following accident and weather data. Each line corresponds to one event:

# %% [markdown]
# 1. car_accident rain lightning wind clouds fire
# 2. fire clouds rain lightning wind
# 3. car_accident fire wind
# 4. clouds rain wind
# 5. lightning fire rain clouds
# 6. clouds wind car_accident
# 7. rain lightning clouds fire
# 8. lightning fire car_accident

# %% [markdown]
# (a) You would like to know what is the likely cause of all the car accidents. What association rules do you need to look for? Compute the confidence and support values for these rules. Looking at these values, which is the most likely cause of the car accidents?

# %% [markdown]
# (b) Find all the association rules for minimal support 0.6 and minimal confidence of 1.0 (certainty). Follow the apriori algorithm.
